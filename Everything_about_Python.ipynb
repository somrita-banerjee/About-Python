# %% [markdown]
# <a href="https://colab.research.google.com/github/somrita-banerjee/About-Python/blob/main/Everything_about_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Intro to Python
#
#
# *   Python is an interpreted, high-level, general- purpose programming language.
# *   It is human-readable, flexible programming language.
# *   It is mainly used in ML, Web development, automation utilities, etc.
# *   Great starter and advanced language.

# %% [markdown]
# ## Prerequisites
#
# * Install Python - https://www.python.org/downloads/
# * Code Editor - I prefer VS code and Collab
